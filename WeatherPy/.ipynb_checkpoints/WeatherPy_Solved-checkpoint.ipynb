# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats
import scipy.stats as st

from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = r"C:\Git\06-Python-APIs\Instructions\output_data\cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
country_codes = []
n = 0

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
   
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        

# Print the city count to confirm sufficient count

len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Define Lists to hold each specific value
temperature = []
humidity = []
latitude = []
longitude = []
cloudiness = []
wind_speed = []
dates = []
country_codes = []

set = 1

#Define URL and define unit type
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
for city in cities:
    query_url = f"{url}appid={weather_api_key}&units={units}&q=" 
#query_url = f"{url}appid={api_key}&units={units}&q="
    response = requests.get(query_url + city).json()
#Append City Data    
    try:
        latitude.append(response["coord"]["lat"])
        temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        longitude.append(response["coord"]["lon"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country_codes.append(response["sys"]["country"])
        dates.append(response["dt"])
    except KeyError:
        print("City not found. Skipping...")
        latitude.append(np.nan)
        temperature.append(np.nan)
        humidity.append(np.nan)
        longitude.append(np.nan)
        country_codes.append(np.nan)
        cloudiness.append(np.nan)
        wind_speed.append(np.nan)
        dates.append(np.nan)
        
    if n == 50:
        n = 0
        set += 1
    else:
        n += 1

#print(f"The weather API responded with: {weather_json}.")
        print(f"Processing record number {n} Set {set} | {[city]}")
#print("______________Data Processing Complete______________________")
# Out:
# Processing record number 1 Set 1 | ['fortuna']
# Processing record number 2 Set 1 | ['santa cruz cabralia']
# Processing record number 3 Set 1 | ['jeremoabo']
# Processing record number 4 Set 1 | ['zakamensk']
# City not found. Skipping...
# Processing record number 5 Set 1 | ['sentyabrskiy']
# Processing record number 6 Set 1 | ['avarua']
# Processing record number 7 Set 1 | ['barrow']
# Processing record number 8 Set 1 | ['east london']
# Processing record number 9 Set 1 | ['hermanus']
# Processing record number 10 Set 1 | ['chokurdakh']
# Processing record number 11 Set 1 | ['wellington']
# City not found. Skipping...
# Processing record number 12 Set 1 | ['taolanaro']
# Processing record number 13 Set 1 | ['rikitea']
# Processing record number 14 Set 1 | ['burgersdorp']
# Processing record number 15 Set 1 | ['verkhoyansk']
# Processing record number 16 Set 1 | ['vila velha']
# Processing record number 17 Set 1 | ['atuona']
# Processing record number 18 Set 1 | ['port hardy']
# Processing record number 19 Set 1 | ['pevek']
# City not found. Skipping...
# Processing record number 20 Set 1 | ['phan rang']
# Processing record number 21 Set 1 | ['dikson']
# Processing record number 22 Set 1 | ['cidreira']
# Processing record number 23 Set 1 | ['havoysund']
# City not found. Skipping...
# Processing record number 24 Set 1 | ['mocambique']
# Processing record number 25 Set 1 | ['mataura']
# Processing record number 26 Set 1 | ['torbay']
# Processing record number 27 Set 1 | ['alice springs']
# Processing record number 28 Set 1 | ['mar del plata']
# Processing record number 29 Set 1 | ['puerto colombia']
# Processing record number 30 Set 1 | ['neepawa']
# Processing record number 31 Set 1 | ['tuktoyaktuk']
# Processing record number 32 Set 1 | ['goure']
# Processing record number 33 Set 1 | ['castro']
# Processing record number 34 Set 1 | ['vila']
# Processing record number 35 Set 1 | ['georgetown']
# Processing record number 36 Set 1 | ['new norfolk']
# Processing record number 37 Set 1 | ['coquimbo']
# Processing record number 38 Set 1 | ['sola']
# Processing record number 39 Set 1 | ['qaanaaq']
# Processing record number 40 Set 1 | ['cape town']
# Processing record number 41 Set 1 | ['dimovo']
# Processing record number 42 Set 1 | ['twin falls']
# Processing record number 43 Set 1 | ['mahebourg']
# Processing record number 44 Set 1 | ['upernavik']
# Processing record number 45 Set 1 | ['hithadhoo']
# Processing record number 46 Set 1 | ['busselton']
# Processing record number 47 Set 1 | ['punta arenas']
# Processing record number 48 Set 1 | ['flinders']
# Processing record number 49 Set 1 | ['husavik']
# Processing record number 50 Set 1 | ['bolitoc']
# Processing record number 1 Set 2 | ['nikolskoye']
# Processing record number 2 Set 2 | ['kavaratti']
# City not found. Skipping...
# Processing record number 3 Set 2 | ['yirol']
# Processing record number 4 Set 2 | ['thompson']
# Processing record number 5 Set 2 | ['pontianak']
# City not found. Skipping...
# Processing record number 6 Set 2 | ['marcona']
# Processing record number 7 Set 2 | ['bredasdorp']
# Processing record number 8 Set 2 | ['leningradskiy']
# Processing record number 9 Set 2 | ['hilo']
# City not found. Skipping...
# Processing record number 10 Set 2 | ['nizhneyansk']
# Processing record number 11 Set 2 | ['talnakh']
# Processing record number 12 Set 2 | ['vao']
# Processing record number 13 Set 2 | ['kapaa']
# Processing record number 14 Set 2 | ['rawson']
# Processing record number 15 Set 2 | ['sao joao da barra']
# Processing record number 16 Set 2 | ['cantagalo']
# Processing record number 17 Set 2 | ['gamba']
# City not found. Skipping...
# Processing record number 18 Set 2 | ['barentsburg']
# Processing record number 19 Set 2 | ['vaini']
# Processing record number 20 Set 2 | ['ponta do sol']
# Processing record number 21 Set 2 | ['egvekinot']
# Processing record number 22 Set 2 | ['emerald']
# Processing record number 23 Set 2 | ['qaqortoq']
# Processing record number 24 Set 2 | ['vestmannaeyjar']
# Processing record number 25 Set 2 | ['bataipora']
# Processing record number 26 Set 2 | ['emmett']
# Processing record number 27 Set 2 | ['hammerfest']
# Processing record number 28 Set 2 | ['kodiak']
# Processing record number 29 Set 2 | ['carnarvon']
# Processing record number 30 Set 2 | ['bozeman']
# Processing record number 31 Set 2 | ['mount isa']
# Processing record number 32 Set 2 | ['tasiilaq']
# Processing record number 33 Set 2 | ['kununurra']
# Processing record number 34 Set 2 | ['hobart']
# Processing record number 35 Set 2 | ['lebu']
# Processing record number 36 Set 2 | ['albany']
# City not found. Skipping...
# Processing record number 37 Set 2 | ['attawapiskat']
# Processing record number 38 Set 2 | ['lasa']
# Processing record number 39 Set 2 | ['tazovskiy']
# Processing record number 40 Set 2 | ['butaritari']
# Processing record number 41 Set 2 | ['makakilo city']
# Processing record number 42 Set 2 | ['vanimo']
# City not found. Skipping...
# Processing record number 43 Set 2 | ['karaul']
# Processing record number 44 Set 2 | ['fatsa']
# City not found. Skipping...
# Processing record number 45 Set 2 | ['belushya guba']
# Processing record number 46 Set 2 | ['akhmim']
# Processing record number 47 Set 2 | ['cherskiy']
# Processing record number 48 Set 2 | ['arraial do cabo']
# Processing record number 49 Set 2 | ['manono']
# Processing record number 50 Set 2 | ['adeje']
# Processing record number 1 Set 3 | ['avera']
# Processing record number 2 Set 3 | ['mayo']
# Processing record number 3 Set 3 | ['cutler ridge']
# Processing record number 4 Set 3 | ['ushuaia']
# Processing record number 5 Set 3 | ['kruisfontein']
# Processing record number 6 Set 3 | ['kahului']
# Processing record number 7 Set 3 | ['luanda']
# Processing record number 8 Set 3 | ['abu samrah']
# Processing record number 9 Set 3 | ['taltal']
# Processing record number 10 Set 3 | ['riverton']
# Processing record number 11 Set 3 | ['shieli']
# Processing record number 12 Set 3 | ['villa carlos paz']
# City not found. Skipping...
# Processing record number 13 Set 3 | ['meyungs']
# Processing record number 14 Set 3 | ['faya']
# City not found. Skipping...
# Processing record number 15 Set 3 | ['grand river south east']
# Processing record number 16 Set 3 | ['saskylakh']
# Processing record number 17 Set 3 | ['narsaq']
# Processing record number 18 Set 3 | ['yagodnoye']
# Processing record number 19 Set 3 | ['ribeira grande']
# Processing record number 20 Set 3 | ['chumikan']
# Processing record number 21 Set 3 | ['khetia']
# Processing record number 22 Set 3 | ['evensk']
# Processing record number 23 Set 3 | ['puerto ayora']
# City not found. Skipping...
# Processing record number 24 Set 3 | ['kamenskoye']
# Processing record number 25 Set 3 | ['peace river']
# Processing record number 26 Set 3 | ['touros']
# City not found. Skipping...
# Processing record number 27 Set 3 | ['malwan']
# Processing record number 28 Set 3 | ['aklavik']
# Processing record number 29 Set 3 | ['roatan']
# Processing record number 30 Set 3 | ['vardo']
# Processing record number 31 Set 3 | ['souillac']
# City not found. Skipping...
# Processing record number 32 Set 3 | ['tumannyy']
# Processing record number 33 Set 3 | ['xingyi']
# Processing record number 34 Set 3 | ['port elizabeth']
# Processing record number 35 Set 3 | ['norman wells']
# Processing record number 36 Set 3 | ['tuatapere']
# Processing record number 37 Set 3 | ['taoudenni']
# Processing record number 38 Set 3 | ['yaan']
# Processing record number 39 Set 3 | ['noumea']
# Processing record number 40 Set 3 | ['havelock']
# Processing record number 41 Set 3 | ['novyy starodub']
# Processing record number 42 Set 3 | ['kaitangata']
# Processing record number 43 Set 3 | ['berlevag']
# Processing record number 44 Set 3 | ['davila']
# Processing record number 45 Set 3 | ['cap malheureux']
# Processing record number 46 Set 3 | ['manikling']
# Processing record number 47 Set 3 | ['xai-xai']
# Processing record number 48 Set 3 | ['singaraja']
# Processing record number 49 Set 3 | ['cabo san lucas']
# Processing record number 50 Set 3 | ['ola']
# Processing record number 1 Set 4 | ['concarneau']
# Processing record number 2 Set 4 | ['aykhal']
# Processing record number 3 Set 4 | ['salinopolis']
# Processing record number 4 Set 4 | ['mariel']
# Processing record number 5 Set 4 | ['kutum']
# Processing record number 6 Set 4 | ['zhezkazgan']
# Processing record number 7 Set 4 | ['elat']
# Processing record number 8 Set 4 | ['faanui']
# Processing record number 9 Set 4 | ['severo-kurilsk']
# Processing record number 10 Set 4 | ['mecca']
# Processing record number 11 Set 4 | ['hiriyur']
# Processing record number 12 Set 4 | ['yellowknife']
# Processing record number 13 Set 4 | ['vanavara']
# Processing record number 14 Set 4 | ['itarema']
# Processing record number 15 Set 4 | ['provideniya']
# Processing record number 16 Set 4 | ['morondava']
# Processing record number 17 Set 4 | ['walvis bay']
# Processing record number 18 Set 4 | ['kodinar']
# Processing record number 19 Set 4 | ['hofn']
# Processing record number 20 Set 4 | ['pyinmana']
# Processing record number 21 Set 4 | ['namibe']
# City not found. Skipping...
# Processing record number 22 Set 4 | ['gurgan']
# Processing record number 23 Set 4 | ['jamestown']
# Processing record number 24 Set 4 | ['aljezur']
# Processing record number 25 Set 4 | ['dingle']
# Processing record number 26 Set 4 | ['catamarca']
# Processing record number 27 Set 4 | ['bluff']
# Processing record number 28 Set 4 | ['tepotzotlan']
# Processing record number 29 Set 4 | ['victoria']
# Processing record number 30 Set 4 | ['lexington']
# Processing record number 31 Set 4 | ['beloha']
# City not found. Skipping...
# Processing record number 32 Set 4 | ['buon me thuot']
# City not found. Skipping...
# Processing record number 33 Set 4 | ['bur gabo']
# Processing record number 34 Set 4 | ['sitka']
# Processing record number 35 Set 4 | ['korhogo']
# Processing record number 36 Set 4 | ['aron']
# Processing record number 37 Set 4 | ['ishigaki']
# Processing record number 38 Set 4 | ['ahmadpur east']
# Processing record number 39 Set 4 | ['san carlos de bariloche']
# Processing record number 40 Set 4 | ['saint-philippe']
# Processing record number 41 Set 4 | ['tecoanapa']
# Processing record number 42 Set 4 | ['pascagoula']
# Processing record number 43 Set 4 | ['kaeo']
# Processing record number 44 Set 4 | ['lagoa']
# Processing record number 45 Set 4 | ['bandarbeyla']
# Processing record number 46 Set 4 | ['arteaga']
# Processing record number 47 Set 4 | ['muros']
# Processing record number 48 Set 4 | ['kuito']
# Processing record number 49 Set 4 | ['batagay']
# Processing record number 50 Set 4 | ['bonaventure']
# City not found. Skipping...
# City not found. Skipping...
# Processing record number 1 Set 5 | ['illoqqortoormiut']
# Processing record number 2 Set 5 | ['baghdad']
# Processing record number 3 Set 5 | ['adre']
# Processing record number 4 Set 5 | ['marawi']
# Processing record number 5 Set 5 | ['belur']
# Processing record number 6 Set 5 | ['zhigansk']
# Processing record number 7 Set 5 | ['turukhansk']
# Processing record number 8 Set 5 | ['ulaanbaatar']
# City not found. Skipping...
# Processing record number 9 Set 5 | ['toliary']
# Processing record number 10 Set 5 | ['clyde river']
# Processing record number 11 Set 5 | ['beian']
# Processing record number 12 Set 5 | ['krasnoturinsk']
# Processing record number 13 Set 5 | ['margate']
# Processing record number 14 Set 5 | ['shitanjing']
# Processing record number 15 Set 5 | ['sharya']
# Processing record number 16 Set 5 | ['port blair']
# Processing record number 17 Set 5 | ['airai']
# City not found. Skipping...
# Processing record number 18 Set 5 | ['burica']
# Processing record number 19 Set 5 | ['tsumeb']
# Processing record number 20 Set 5 | ['college']
# Processing record number 21 Set 5 | ['rafaela']
# City not found. Skipping...
# Processing record number 22 Set 5 | ['tsihombe']
# Processing record number 23 Set 5 | ['linxia']
# Processing record number 24 Set 5 | ['kosh-agach']
# Processing record number 25 Set 5 | ['san jeronimo']
# Processing record number 26 Set 5 | ['ahipara']
# Processing record number 27 Set 5 | ['vostok']
# Processing record number 28 Set 5 | ['aleppo']
# Processing record number 29 Set 5 | ['pahrump']
# Processing record number 30 Set 5 | ['nalut']
# Processing record number 31 Set 5 | ['pisco']
# Processing record number 32 Set 5 | ['boa vista']
# City not found. Skipping...
# Processing record number 33 Set 5 | ['crab hill']
# Processing record number 34 Set 5 | ['westport']
# City not found. Skipping...
# Processing record number 35 Set 5 | ['palabuhanratu']
# Processing record number 36 Set 5 | ['bengkulu']
# Processing record number 37 Set 5 | ['belyy']
# Processing record number 38 Set 5 | ['plettenberg bay']
# Processing record number 39 Set 5 | ['hambantota']
# Processing record number 40 Set 5 | ['shivrajpur']
# Processing record number 41 Set 5 | ['savantvadi']
# Processing record number 42 Set 5 | ['nanortalik']
# City not found. Skipping...
# Processing record number 43 Set 5 | ['promysla']
# Processing record number 44 Set 5 | ['roald']
# City not found. Skipping...
# Processing record number 45 Set 5 | ['hihifo']
# Processing record number 46 Set 5 | ['yanam']
# Processing record number 47 Set 5 | ['alugan']
# Processing record number 48 Set 5 | ['mount gambier']
# Processing record number 49 Set 5 | ['chimala']
# Processing record number 50 Set 5 | ['bambous virieux']
# City not found. Skipping...
# Processing record number 1 Set 6 | ['amderma']
# Processing record number 2 Set 6 | ['kargasok']
# City not found. Skipping...
# Processing record number 3 Set 6 | ['scottsburgh']
# Processing record number 4 Set 6 | ['panormos']
# Processing record number 5 Set 6 | ['katowice']
# Processing record number 6 Set 6 | ['san cristobal']
# Processing record number 7 Set 6 | ['constitucion']
# Processing record number 8 Set 6 | ['cockburn town']
# Processing record number 9 Set 6 | ['praya']
# Processing record number 10 Set 6 | ['chunskiy']
# Processing record number 11 Set 6 | ['tilichiki']
# Processing record number 12 Set 6 | ['krasnoborsk']
# Processing record number 13 Set 6 | ['arusha']
# Processing record number 14 Set 6 | ['ambon']
# Processing record number 15 Set 6 | ['jijiga']
# City not found. Skipping...
# Processing record number 16 Set 6 | ['mutsamudu']
# Processing record number 17 Set 6 | ['jacqueville']
# Processing record number 18 Set 6 | ['tarauaca']
# Processing record number 19 Set 6 | ['salalah']
# Processing record number 20 Set 6 | ['brae']
# Processing record number 21 Set 6 | ['ugoofaaru']
# Processing record number 22 Set 6 | ['zella-mehlis']
# Processing record number 23 Set 6 | ['angul']
# Processing record number 24 Set 6 | ['coihaique']
# Processing record number 25 Set 6 | ['san quintin']
# Processing record number 26 Set 6 | ['kismayo']
# Processing record number 27 Set 6 | ['saravan']
# Processing record number 28 Set 6 | ['alofi']
# Processing record number 29 Set 6 | ['ixtapa']
# Processing record number 30 Set 6 | ['bhadrachalam']
# City not found. Skipping...
# Processing record number 31 Set 6 | ['jiddah']
# Processing record number 32 Set 6 | ['matagami']
# Processing record number 33 Set 6 | ['half moon bay']
# City not found. Skipping...
# Processing record number 34 Set 6 | ['mys shmidta']
# Processing record number 35 Set 6 | ['avon park']
# Processing record number 36 Set 6 | ['laguna']
# Processing record number 37 Set 6 | ['isangel']
# Processing record number 38 Set 6 | ['deputatskiy']
# Processing record number 39 Set 6 | ['villa maria']
# Processing record number 40 Set 6 | ['lavrentiya']
# Processing record number 41 Set 6 | ['bisira']
# Processing record number 42 Set 6 | ['turayf']
# Processing record number 43 Set 6 | ['fairbanks']
# Processing record number 44 Set 6 | ['chuy']
# Processing record number 45 Set 6 | ['belaya gora']
# City not found. Skipping...
# Processing record number 46 Set 6 | ['vaitupu']
# Processing record number 47 Set 6 | ['aswan']
# Processing record number 48 Set 6 | ['viedma']
# Processing record number 49 Set 6 | ['te anau']
# Processing record number 50 Set 6 | ['zhangjiakou']
# Processing record number 1 Set 7 | ['misratah']
# Processing record number 2 Set 7 | ['wattens']
# Processing record number 3 Set 7 | ['porto novo']
# Processing record number 4 Set 7 | ['bathsheba']
# Processing record number 5 Set 7 | ['assiniboia']
# Processing record number 6 Set 7 | ['satipo']
# Processing record number 7 Set 7 | ['seoul']
# Processing record number 8 Set 7 | ['biak']
# Processing record number 9 Set 7 | ['camacha']
# Processing record number 10 Set 7 | ['meulaboh']
# Processing record number 11 Set 7 | ['waingapu']
# Processing record number 12 Set 7 | ['canavieiras']
# Processing record number 13 Set 7 | ['kudahuvadhoo']
# Processing record number 14 Set 7 | ['eyl']
# Processing record number 15 Set 7 | ['geraldton']
# Processing record number 16 Set 7 | ['hay river']
# Processing record number 17 Set 7 | ['lata']
# Processing record number 18 Set 7 | ['dasoguz']
# Processing record number 19 Set 7 | ['ust-omchug']
# Processing record number 20 Set 7 | ['ust-karsk']
# Processing record number 21 Set 7 | ['longyearbyen']
# Processing record number 22 Set 7 | ['anloga']
# Processing record number 23 Set 7 | ['sembakung']
# Processing record number 24 Set 7 | ['ormara']
# City not found. Skipping...
# Processing record number 25 Set 7 | ['vitimskiy']
# Processing record number 26 Set 7 | ['christchurch']
# Processing record number 27 Set 7 | ['lagunas']
# Processing record number 28 Set 7 | ['ayagoz']
# Processing record number 29 Set 7 | ['atar']
# Processing record number 30 Set 7 | ['wagar']
# Processing record number 31 Set 7 | ['sundargarh']
# Processing record number 32 Set 7 | ['shakawe']
# Processing record number 33 Set 7 | ['parry sound']
# Processing record number 34 Set 7 | ['isla mujeres']
# Processing record number 35 Set 7 | ['road town']
# Processing record number 36 Set 7 | ['mutoko']
# Processing record number 37 Set 7 | ['nicoya']
# Processing record number 38 Set 7 | ['waipawa']
# Processing record number 39 Set 7 | ['elko']
# Processing record number 40 Set 7 | ['abrau-dyurso']
# City not found. Skipping...
# Processing record number 41 Set 7 | ['tabiauea']
# Processing record number 42 Set 7 | ['chihuahua']
# Processing record number 43 Set 7 | ['dalvik']
# Processing record number 44 Set 7 | ['slave lake']
# Processing record number 45 Set 7 | ['kungurtug']
# Processing record number 46 Set 7 | ['beisfjord']
# Processing record number 47 Set 7 | ['mauriti']
# Processing record number 48 Set 7 | ['tirunelveli']
# Processing record number 49 Set 7 | ['padang']
# Processing record number 50 Set 7 | ['okara']
# Processing record number 1 Set 8 | ['skegness']
# Processing record number 2 Set 8 | ['nemuro']
# Processing record number 3 Set 8 | ['erzin']
# Processing record number 4 Set 8 | ['ajdabiya']
# Processing record number 5 Set 8 | ['monte alegre']
# Processing record number 6 Set 8 | ['merrill']
# Processing record number 7 Set 8 | ['krasnokamensk']
# Processing record number 8 Set 8 | ['hasaki']
# Processing record number 9 Set 8 | ['deoranian']
# Processing record number 10 Set 8 | ['inhambane']
# Processing record number 11 Set 8 | ['rosetta']
# Processing record number 12 Set 8 | ['puerto madryn']
# Processing record number 13 Set 8 | ['paris']
# Processing record number 14 Set 8 | ['tongren']
# Processing record number 15 Set 8 | ['svay rieng']
# Processing record number 16 Set 8 | ['dwarka']
# Processing record number 17 Set 8 | ['goundi']
# Processing record number 18 Set 8 | ['haines junction']
# Processing record number 19 Set 8 | ['saint-pierre']
# Processing record number 20 Set 8 | ['barinitas']
# Processing record number 21 Set 8 | ['cambrai']
# Processing record number 22 Set 8 | ['hualmay']
# Processing record number 23 Set 8 | ['gondar']
# City not found. Skipping...
# Processing record number 24 Set 8 | ['babanusah']
# Processing record number 25 Set 8 | ['morant bay']
# Processing record number 26 Set 8 | ['fenoarivo']
# Processing record number 27 Set 8 | ['kyzyl-suu']
# City not found. Skipping...
# Processing record number 28 Set 8 | ['rungata']
# Processing record number 29 Set 8 | ['zagora']
# Processing record number 30 Set 8 | ['dharchula']
# Processing record number 31 Set 8 | ['vila franca do campo']
# Processing record number 32 Set 8 | ['beni']
# Processing record number 33 Set 8 | ['aripuana']
# Processing record number 34 Set 8 | ['necochea']
# Processing record number 35 Set 8 | ['calabozo']
# Processing record number 36 Set 8 | ['svetlaya']
# Processing record number 37 Set 8 | ['junagarh']
# Processing record number 38 Set 8 | ['vestmanna']
# Processing record number 39 Set 8 | ['mantua']
# Processing record number 40 Set 8 | ['tiksi']
# Processing record number 41 Set 8 | ['tommot']
# Processing record number 42 Set 8 | ['auki']
# Processing record number 43 Set 8 | ['genhe']
# Processing record number 44 Set 8 | ['grootfontein']
# Processing record number 45 Set 8 | ['elliot']
# Processing record number 46 Set 8 | ['mogadishu']
# Processing record number 47 Set 8 | ['quatre cocos']
# Processing record number 48 Set 8 | ['albania']
# Processing record number 49 Set 8 | ['bonoua']
# Processing record number 50 Set 8 | ['ryotsu']
# Processing record number 1 Set 9 | ['bambui']
# Processing record number 2 Set 9 | ['wamba']
# Processing record number 3 Set 9 | ['garowe']
# Processing record number 4 Set 9 | ['formiga']
# Processing record number 5 Set 9 | ['galveston']
# Processing record number 6 Set 9 | ['luderitz']
# City not found. Skipping...
# Processing record number 7 Set 9 | ['sedelnikovo']
# Processing record number 8 Set 9 | ['sakakah']
# Processing record number 9 Set 9 | ['winnemucca']
# City not found. Skipping...
# Processing record number 10 Set 9 | ['samusu']
# Processing record number 11 Set 9 | ['aktash']
# Processing record number 12 Set 9 | ['novoagansk']
# Processing record number 13 Set 9 | ['panaba']
# Processing record number 14 Set 9 | ['rovnoye']
# Processing record number 15 Set 9 | ['ust-ishim']
# Processing record number 16 Set 9 | ['porto velho']
# City not found. Skipping...
# Processing record number 17 Set 9 | ['beruni']
# Processing record number 18 Set 9 | ['pacific grove']
# Processing record number 19 Set 9 | ['hamilton']
# Processing record number 20 Set 9 | ['klaksvik']
# Processing record number 21 Set 9 | ['dawson creek']
# Processing record number 22 Set 9 | ['sept-iles']
# Processing record number 23 Set 9 | ['ray']
# Processing record number 24 Set 9 | ['dali']
# Processing record number 25 Set 9 | ['amapa']
# Processing record number 26 Set 9 | ['mbulu']
# Processing record number 27 Set 9 | ['guiyang']
# Processing record number 28 Set 9 | ['bambanglipuro']
# Processing record number 29 Set 9 | ['primo tapia']
# Processing record number 30 Set 9 | ['pangnirtung']
# Processing record number 31 Set 9 | ['stephenville']
# Processing record number 32 Set 9 | ['borujerd']
# Processing record number 33 Set 9 | ['marzuq']
# Processing record number 34 Set 9 | ['sisimiut']
# Processing record number 35 Set 9 | ['tezu']
# Processing record number 36 Set 9 | ['kieta']
# City not found. Skipping...
# Processing record number 37 Set 9 | ['gardan diwal']
# Processing record number 38 Set 9 | ['ternate']
# Processing record number 39 Set 9 | ['yulara']
# Processing record number 40 Set 9 | ['shenzhen']
# Processing record number 41 Set 9 | ['kuandian']
# Processing record number 42 Set 9 | ['sioux lookout']
# City not found. Skipping...
# Processing record number 43 Set 9 | ['bajo baudo']
# Processing record number 44 Set 9 | ['santa maria']
# Processing record number 45 Set 9 | ['oistins']
# Processing record number 46 Set 9 | ['nakamura']
# Processing record number 47 Set 9 | ['iqaluit']
# Processing record number 48 Set 9 | ['fomboni']
# Processing record number 49 Set 9 | ['waw']
# City not found. Skipping...
# Processing record number 50 Set 9 | ['lolua']
# Processing record number 1 Set 10 | ['tucuma']
# Processing record number 2 Set 10 | ['krasnoselkup']
# Processing record number 3 Set 10 | ['shimoda']
# Processing record number 4 Set 10 | ['pitimbu']
# Processing record number 5 Set 10 | ['nishihara']
# Processing record number 6 Set 10 | ['sangar']
# Processing record number 7 Set 10 | ['cibitoke']
# Processing record number 8 Set 10 | ['mannheim']
# Processing record number 9 Set 10 | ['muswellbrook']
# Processing record number 10 Set 10 | ['bowen']
# Processing record number 11 Set 10 | ['kijang']
# Processing record number 12 Set 10 | ['kuytun']
# Processing record number 13 Set 10 | ['monrovia']
# City not found. Skipping...
# Processing record number 14 Set 10 | ['fort saint john']
# Processing record number 15 Set 10 | ['corinth']
# Processing record number 16 Set 10 | ['saint george']
# Processing record number 17 Set 10 | ['kpandu']
# Processing record number 18 Set 10 | ['banda aceh']
# Processing record number 19 Set 10 | ['stornoway']
# Processing record number 20 Set 10 | ['burgeo']
# Processing record number 21 Set 10 | ['jiayuguan']
# Processing record number 22 Set 10 | ['bhatgaon']
# Processing record number 23 Set 10 | ['kanakapura']
# Processing record number 24 Set 10 | ['kavieng']
# Processing record number 25 Set 10 | ['kanniyakumari']
# Processing record number 26 Set 10 | ['tall kayf']
# Processing record number 27 Set 10 | ['mocuba']
# Processing record number 28 Set 10 | ['grindavik']
# Processing record number 29 Set 10 | ['caconda']
# Processing record number 30 Set 10 | ['rudbar']
# Processing record number 31 Set 10 | ['novyy urengoy']
# Processing record number 32 Set 10 | ['ilulissat']
# Processing record number 33 Set 10 | ['sedro-woolley']
# Processing record number 34 Set 10 | ['luba']
# Processing record number 35 Set 10 | ['nara']
# Processing record number 36 Set 10 | ['portland']
# Processing record number 37 Set 10 | ['ingham']
# Processing record number 38 Set 10 | ['barcelos']
# Processing record number 39 Set 10 | ['adrar']
# City not found. Skipping...
# Processing record number 40 Set 10 | ['warqla']
# Processing record number 41 Set 10 | ['barra patuca']
# Processing record number 42 Set 10 | ['saint-joseph']
# Processing record number 43 Set 10 | ['olinda']
# Processing record number 44 Set 10 | ['colac']
# Processing record number 45 Set 10 | ['palmer']
# Processing record number 46 Set 10 | ['payo']
# Processing record number 47 Set 10 | ['sol-iletsk']
# Processing record number 48 Set 10 | ['lapy']
# Processing record number 49 Set 10 | ['el seibo']
# Processing record number 50 Set 10 | ['nuuk']
# Processing record number 1 Set 11 | ['vicuna']
# Processing record number 2 Set 11 | ['ara']
# Processing record number 3 Set 11 | ['kupino']
# Processing record number 4 Set 11 | ['kopavogur']
# Processing record number 5 Set 11 | ['coahuayana']
# Processing record number 6 Set 11 | ['port hueneme']
# Processing record number 7 Set 11 | ['sorong']
# Processing record number 8 Set 11 | ['buraydah']
# Processing record number 9 Set 11 | ['qasigiannguit']
# Processing record number 10 Set 11 | ['ancud']
# Processing record number 11 Set 11 | ['hadrut']
# Processing record number 12 Set 11 | ['badou']
# Processing record number 13 Set 11 | ['meadow lake']
# Processing record number 14 Set 11 | ['port hedland']
# Processing record number 15 Set 11 | ['joacaba']
# Processing record number 16 Set 11 | ['santo tomas']
# Processing record number 17 Set 11 | ['gweta']
# Processing record number 18 Set 11 | ['corn island']
# Processing record number 19 Set 11 | ['mata']
# Processing record number 20 Set 11 | ['puerto narino']
# Processing record number 21 Set 11 | ['byron bay']
# Processing record number 22 Set 11 | ['urbano santos']
# Processing record number 23 Set 11 | ['rio gallegos']
# Processing record number 24 Set 11 | ['surt']
# Processing record number 25 Set 11 | ['topeka']
# Processing record number 26 Set 11 | ['novosergiyevka']
# Processing record number 27 Set 11 | ['kaka']
# Processing record number 28 Set 11 | ['mahanoro']
# Processing record number 29 Set 11 | ['the pas']
# Processing record number 30 Set 11 | ['katsuura']
# Processing record number 31 Set 11 | ['wilmington']
# Processing record number 32 Set 11 | ['broken hill']
# Processing record number 33 Set 11 | ['namatanai']
# Processing record number 34 Set 11 | ['augusto correa']
# Processing record number 35 Set 11 | ['ostrovnoy']
# Processing record number 36 Set 11 | ['virginia beach']
# Processing record number 37 Set 11 | ['nyurba']
# Processing record number 38 Set 11 | ['toora-khem']
# Processing record number 39 Set 11 | ['maniitsoq']
# Processing record number 40 Set 11 | ['lompoc']
# Processing record number 41 Set 11 | ['eureka']
# Processing record number 42 Set 11 | ['ambilobe']
# Processing record number 43 Set 11 | ['cape canaveral']
# Processing record number 44 Set 11 | ['samarai']
# Processing record number 45 Set 11 | ['wildwood']
# Processing record number 46 Set 11 | ['phibun mangsahan']
# City not found. Skipping...
# Processing record number 47 Set 11 | ['asayita']
# Processing record number 48 Set 11 | ['marsh harbour']
# Processing record number 49 Set 11 | ['tautira']
# Processing record number 50 Set 11 | ['pasni']
# Processing record number 1 Set 12 | ['oga']
# Processing record number 2 Set 12 | ['puri']
# Processing record number 3 Set 12 | ['thunder bay']
# Processing record number 4 Set 12 | ['vaitape']
# Processing record number 5 Set 12 | ['metro']
# Processing record number 6 Set 12 | ['kuybysheve']
# Processing record number 7 Set 12 | ['arandis']
# Processing record number 8 Set 12 | ['yerofey pavlovich']
# Processing record number 9 Set 12 | ['jalu']
# Processing record number 10 Set 12 | ['nouadhibou']
# Processing record number 11 Set 12 | ['suraabad']
# Processing record number 12 Set 12 | ['naica']
# City not found. Skipping...
# Processing record number 13 Set 12 | ['bolungarvik']
# Processing record number 14 Set 12 | ['matay']
# Processing record number 15 Set 12 | ['sao filipe']
# Processing record number 16 Set 12 | ['shafranovo']
# Processing record number 17 Set 12 | ['diu']
# Processing record number 18 Set 12 | ['takoradi']
# Processing record number 19 Set 12 | ['gagino']
# Processing record number 20 Set 12 | ['douglas']
# Processing record number 21 Set 12 | ['huarmey']
# Processing record number 22 Set 12 | ['lodwar']
# Processing record number 23 Set 12 | ['caluquembe']
# Processing record number 24 Set 12 | ['port pirie']
# Processing record number 25 Set 12 | ['chapais']
# Processing record number 26 Set 12 | ['saint-augustin']
# Processing record number 27 Set 12 | ['praia da vitoria']
# Processing record number 28 Set 12 | ['chimoio']
# Processing record number 29 Set 12 | ['lewistown']
# Processing record number 30 Set 12 | ['asau']
# Processing record number 31 Set 12 | ['nizhneudinsk']
# Processing record number 32 Set 12 | ['ponta delgada']
# Processing record number 33 Set 12 | ['ada']
# Processing record number 34 Set 12 | ['paamiut']
# Processing record number 35 Set 12 | ['kokologo']
# Processing record number 36 Set 12 | ['tharad']
# Processing record number 37 Set 12 | ['ushtobe']
# Processing record number 38 Set 12 | ['talhar']
# Processing record number 39 Set 12 | ['oranjemund']
# Processing record number 40 Set 12 | ['amazar']
# Processing record number 41 Set 12 | ['ocos']
# Processing record number 42 Set 12 | ['agua verde']
# Processing record number 43 Set 12 | ['jatiroto']
# City not found. Skipping...
# Processing record number 44 Set 12 | ['raozan']
# Processing record number 45 Set 12 | ['fontem']
# Processing record number 46 Set 12 | ['hervey bay']
# Processing record number 47 Set 12 | ['kargil']
# Processing record number 48 Set 12 | ['mao']
# Processing record number 49 Set 12 | ['broome']

# %%
#This is only testing and notes section
#* Northern Hemisphere - Temperature (F) vs. Latitude
#* Southern Hemisphere - Temperature (F) vs. Latitude
#* Northern Hemisphere - Humidity (%) vs. Latitude
#* Southern Hemisphere - Humidity (%) vs. Latitude
#* Northern Hemisphere - Cloudiness (%) vs. Latitude
#* Southern Hemisphere - Cloudiness (%) vs. Latitude
#* Northern Hemisphere - Wind Speed (mph) vs. Latitude
#* Southern Hemisphere - Wind Speed (mph) vs. Latitude
#len(temperature)
#len(humidity)
#len(latitude)
#len(longitude)
#len(cloudiness)
#len(wind_speed)
#len(dates)
#len(country_codes)
#len(cities)

# %%
#Convert raw data to Dataframe from previously created lists
cities_df = pd.DataFrame({"City": cities,
                           "Lat": latitude,
                           "Lng": longitude,
                            "Max Temp": temperature,
                           "Humidity": humidity,
                           "Cloudiness": cloudiness,
                           "Wind Speed": wind_speed,
                           "Country": country_codes,
                           "Date": dates,
                          })

# %%
#Drop any NA values out of Dataframe and print new number of cities and show header of Dataframe
cities_df = cities_df.dropna(how='any')
print(f"Number of cities: {len(cities_df)}")
cities_df.head(10)
# Out:
# Number of cities: 561
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               fortuna  40.5982 -124.1573     62.42      69.0        75.0
# 1   santa cruz cabralia -16.2781  -39.0247     80.83      65.0        40.0
# 2             jeremoabo -10.0750  -38.4808     79.61      63.0        87.0
# 3             zakamensk  50.3741  103.2863     27.84      89.0        15.0
# 5                avarua -21.2078 -159.7750     75.25      69.0        12.0
# 6                barrow  71.2906 -156.7887     -5.78      77.0         1.0
# 7           east london -33.0153   27.9116     65.39      83.0        80.0
# 8              hermanus -34.4187   19.2345     62.91      88.0        69.0
# 9            chokurdakh  70.6333  147.9167    -15.92      98.0        99.0
# 10           wellington -41.2866  174.7756     58.77      93.0        90.0
#
#     Wind Speed Country          Date
# 0         3.00      US  1.635531e+09
# 1         9.22      BR  1.635531e+09
# 2         9.17      BR  1.635531e+09
# 3         2.26      RU  1.635531e+09
# 5         8.05      CK  1.635531e+09
# 6        10.36      US  1.635531e+09
# 7        15.88      ZA  1.635531e+09
# 8         8.46      ZA  1.635531e+09
# 9         3.38      RU  1.635531e+09
# 10        1.14      NZ  1.635531e+09

# %%
cities_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  561.000000  561.000000  561.000000  561.000000  561.000000  561.000000
# mean    19.995301   15.291257   60.914242   70.395722   59.217469    7.823405
# std     32.744087   88.949028   22.457426   20.660874   38.305060    5.469095
# min    -54.800000 -179.166700  -18.170000   10.000000    0.000000    0.000000
# 25%     -7.300000  -65.038500   47.710000   58.000000   20.000000    3.650000
# 50%     22.900000   21.850000   66.720000   74.000000   75.000000    6.800000
# 75%     46.616600   85.100000   77.680000   87.000000   96.000000   10.650000
# max     78.218600  178.416700   98.060000  100.000000  100.000000   31.880000
#
#                Date
# count  5.610000e+02
# mean   1.635531e+09
# std    1.049937e+02
# min    1.635531e+09
# 25%    1.635531e+09
# 50%    1.635531e+09
# 75%    1.635531e+09
# max    1.635531e+09

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#For Dataframe info please reffer to Output above

# %%
#Export cities_df Dataframe into csv file that will be located in output_data folder
cities_df.to_csv(r'C:\Git\python-api-challenge\output_data\cities_2.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_above_100 = cities_df.loc[cities_df["Humidity"] > 100]
print("Cities with humidity above 100%")
humidity_above_100
# Out:
# Cities with humidity above 100%
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
humidity_above_100.count()
# Out:
# City          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# Country       0
# Date          0
# dtype: int64

# %% [markdown]
# #It appears that there are no cities with humidity above 100%

# %% [markdown]
# #Lets check number of items below or equal to 100%

# %%
humidity_within_100 = cities_df.loc[cities_df["Humidity"] <= 100]
print("Cities with humidity below or equal to 100%")
humidity_within_100
# Out:
# Cities with humidity below or equal to 100%
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                fortuna  40.5982 -124.1573     62.42      69.0        75.0
# 1    santa cruz cabralia -16.2781  -39.0247     80.83      65.0        40.0
# 2              jeremoabo -10.0750  -38.4808     79.61      63.0        87.0
# 3              zakamensk  50.3741  103.2863     27.84      89.0        15.0
# 5                 avarua -21.2078 -159.7750     75.25      69.0        12.0
# ..                   ...      ...       ...       ...       ...         ...
# 605               fontem   5.4685    9.8818     68.16      91.0        97.0
# 606           hervey bay -25.2986  152.8535     77.04      85.0       100.0
# 607               kargil  34.5667   76.1000     30.38      56.0        39.0
# 608                  mao  39.8885    4.2658     66.76      72.0        20.0
# 609               broome  42.2506  -75.8330     56.98      57.0        75.0
#
#      Wind Speed Country          Date
# 0          3.00      US  1.635531e+09
# 1          9.22      BR  1.635531e+09
# 2          9.17      BR  1.635531e+09
# 3          2.26      RU  1.635531e+09
# 5          8.05      CK  1.635531e+09
# ..          ...     ...           ...
# 605        4.74      CM  1.635531e+09
# 606       13.60      AU  1.635531e+09
# 607        4.34      IN  1.635531e+09
# 608        9.22      ES  1.635531e+09
# 609        3.00      US  1.635531e+09
#
# [561 rows x 9 columns]

# %%
#Obviously we don't have cities that are above 100%
humidity_within_100.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
#Renaming cities_df to clean_city_df even though we don't have cities that exceed humidity above 100!

# %%
clean_city_data = cities_df

# %%
clean_city_data.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              fortuna  40.5982 -124.1573     62.42      69.0        75.0
# 1  santa cruz cabralia -16.2781  -39.0247     80.83      65.0        40.0
# 2            jeremoabo -10.0750  -38.4808     79.61      63.0        87.0
# 3            zakamensk  50.3741  103.2863     27.84      89.0        15.0
# 5               avarua -21.2078 -159.7750     75.25      69.0        12.0
#
#    Wind Speed Country          Date
# 0        3.00      US  1.635531e+09
# 1        9.22      BR  1.635531e+09
# 2        9.17      BR  1.635531e+09
# 3        2.26      RU  1.635531e+09
# 5        8.05      CK  1.635531e+09

# %%
clean_city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  561.000000  561.000000  561.000000  561.000000  561.000000  561.000000
# mean    19.995301   15.291257   60.914242   70.395722   59.217469    7.823405
# std     32.744087   88.949028   22.457426   20.660874   38.305060    5.469095
# min    -54.800000 -179.166700  -18.170000   10.000000    0.000000    0.000000
# 25%     -7.300000  -65.038500   47.710000   58.000000   20.000000    3.650000
# 50%     22.900000   21.850000   66.720000   74.000000   75.000000    6.800000
# 75%     46.616600   85.100000   77.680000   87.000000   96.000000   10.650000
# max     78.218600  178.416700   98.060000  100.000000  100.000000   31.880000
#
#                Date
# count  5.610000e+02
# mean   1.635531e+09
# std    1.049937e+02
# min    1.635531e+09
# 25%    1.635531e+09
# 50%    1.635531e+09
# 75%    1.635531e+09
# max    1.635531e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Scatter 
lat = clean_city_data.iloc[:,1]
temp_max = clean_city_data.iloc[:,3]

plt.figure(figsize=(10,7))
plt.scatter(lat, temp_max,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)
plt.xlim(-60,90)
plt.ylim(min(clean_city_data['Max Temp']) - 10, max(clean_city_data['Max Temp']) + 10)
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.title(f"Latitude vs. Max Temperature ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\Lat_MaxTemp_Fig1.png")

# %% [markdown]
# *Looking at Latitude versus temperature plot above we can see obvious drop in temperature as it moves away from equator
# *Bigger drop in temperature is visible on Northern Hemisphere, basically on positive latitude temperature drop is more
# *significant
# *Additionally, it is important to note that our data sample contains more samples from Norther. Hemisphere due to the way
# *data is collected

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Scatter plot Latitude vd. Humidity worldwide sample
lat = clean_city_data.iloc[:,1]
humidity = clean_city_data.iloc[:,4]
plt.figure(figsize=(10,7))

# Plot the lat vs humidity
plt.scatter(x = lat, y = humidity,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)
plt.xlim(-80,100)
plt.ylim(min(clean_city_data['Humidity']) - 17, max(clean_city_data['Humidity']) + 20)
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.title(f"Latitude vs. Humidity (%) ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\Lat_Humidity_Fig2.png")

# %% [markdown]
# *Looking at Latitude versus Humidity plot above we can see that clodiness is fairly evenly distributed.
# *Northern Hemisphere has more data collections, and it appears more dense ad slightly higher Humidity as we go
# *further north
# *Please note, our latitude distribution is from approximately -60 to +80, so there is more data on positive side

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat = clean_city_data.iloc[:,1]
cloudiness = clean_city_data.iloc[:,5]
plt.figure(figsize=(10,7))

# Plot the lat vs the cloudiness
plt.scatter(x = lat, y = cloudiness,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)
plt.xlim(-80,100)
plt.ylim(min(clean_city_data['Cloudiness']) - 17, max(clean_city_data['Cloudiness']) + 20)
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.title(f"Latitude vs. Cloudiness ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\Lat_Cloudiness_Fig3.png")

# %% [markdown]
# *Looking at Latitude versus Cloudiness plot above we can see that Cloudiness is fairly evenly distributed, increasing as we
# *latitude increases northwards
# *Northern Hemisphere has more data collections, and it appears more dense and slightly higher Cloudiness as we go
# *further north
# *Please note, our latitude distribution is from approximately -60 to +80, so there is more data on positive side

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat = clean_city_data.iloc[:,1]
wind_speed = clean_city_data.iloc[:,6]
plt.figure(figsize=(10,7))

# Plot the lat vs the wind speed
plt.scatter(x = lat, y = wind_speed,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)
plt.xlim(-80,100)
plt.ylim(min(clean_city_data['Wind Speed']) - 10, max(clean_city_data['Wind Speed']) + 10)
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.title(f"Latitude vs. Wind Speed ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\Lat_WindSpeed_Fig4.png")

# %% [markdown]
# *Looking at Latitude versus Wind Speed plot above we can see that Wind Speed is fairly evenly distributed, with some
# *outliers -55 and +35 Latitude
# *Northern Hemisphere has more data collections, and it appears more dense on the scatter plot

# %% [markdown]
# ## Linear Regression

# %%
#Northern Hemisphere separation
northern_hemisphere = clean_city_data.loc[clean_city_data["Lat"] >= 0]
len(northern_hemisphere)
northern_hemisphere.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       fortuna  40.5982 -124.1573     62.42      69.0        75.0
# 3     zakamensk  50.3741  103.2863     27.84      89.0        15.0
# 6        barrow  71.2906 -156.7887     -5.78      77.0         1.0
# 9    chokurdakh  70.6333  147.9167    -15.92      98.0        99.0
# 14  verkhoyansk  67.5447  133.3850      7.99      95.0       100.0
# 17   port hardy  50.6996 -127.4199     46.27      73.0        14.0
# 18        pevek  69.7008  170.3133     -1.93      96.0        98.0
# 20       dikson  73.5069   80.5464      6.66      86.0       100.0
# 22    havoysund  70.9963   24.6622     40.08      67.0       100.0
# 25       torbay  47.6666  -52.7314     41.40      92.0       100.0
#
#     Wind Speed Country          Date
# 0         3.00      US  1.635531e+09
# 3         2.26      RU  1.635531e+09
# 6        10.36      US  1.635531e+09
# 9         3.38      RU  1.635531e+09
# 14        2.98      RU  1.635531e+09
# 17       18.14      CA  1.635531e+09
# 18        2.64      RU  1.635531e+09
# 20       15.75      RU  1.635531e+09
# 22       31.88      NO  1.635531e+09
# 25       18.01      CA  1.635531e+09

# %%
#Southern Hemisphere separation
southern_hemisphere = clean_city_data.loc[clean_city_data["Lat"] < 0]
len(southern_hemisphere)
southern_hemisphere.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1   santa cruz cabralia -16.2781  -39.0247     80.83      65.0        40.0
# 2             jeremoabo -10.0750  -38.4808     79.61      63.0        87.0
# 5                avarua -21.2078 -159.7750     75.25      69.0        12.0
# 7           east london -33.0153   27.9116     65.39      83.0        80.0
# 8              hermanus -34.4187   19.2345     62.91      88.0        69.0
# 10           wellington -41.2866  174.7756     58.77      93.0        90.0
# 12              rikitea -23.1203 -134.9692     75.40      76.0       100.0
# 13          burgersdorp -30.9977   26.3286     61.12      31.0        27.0
# 15           vila velha -20.3297  -40.2925     80.55      69.0        75.0
# 16               atuona  -9.8000 -139.0333     77.94      69.0        75.0
#
#     Wind Speed Country          Date
# 1         9.22      BR  1.635531e+09
# 2         9.17      BR  1.635531e+09
# 5         8.05      CK  1.635531e+09
# 7        15.88      ZA  1.635531e+09
# 8         8.46      ZA  1.635531e+09
# 10        1.14      NZ  1.635531e+09
# 12       18.66      PF  1.635531e+09
# 13       11.50      ZA  1.635531e+09
# 15       11.50      BR  1.635531e+09
# 16       12.35      PF  1.635531e+09

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform a linear regression on Latitude North versus Maximum Temperature 
lat_n = northern_hemisphere.iloc[:,1]
max_temp_n = northern_hemisphere.iloc[:,3]
#Calculate Correlation Coefficient
print(f"The r-value is {round(st.pearsonr(lat_n,max_temp_n)[0],2)}")
(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = linregress(lat_n, max_temp_n)
# Create equation of line to calculate predicted violent crime rate
vc_fit = vc_slope * lat_n + vc_int
# Plot the linear model on top of scatter plot 
plt.figure(figsize=(10,7))
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.scatter(lat_n, max_temp_n,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

plt.plot(lat_n,vc_fit,"--")
plt.xlim(-10,90)
plt.ylim(min(northern_hemisphere['Max Temp']) - 17, max(northern_hemisphere['Max Temp']) + 20)
plt.title(f"Latitude vs. Max Temperature (North H.) ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.plot(lat_n,vc_fit,"--")
plt.show()
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\NH_Lat_MaxTemp_Fig5.png")
# Out:
# The r-value is -0.86

# %% [markdown]
# *Looking at the graph and linear regression above for Northern Hemisphere we can see that temperature rises with
# *approach of equator
# *Note, our data collection has more data samples further north making linear regression and r-value more significant

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform a linear regression on Latitude South versus Maximum Temperature 
lat_s = southern_hemisphere.iloc[:,1]
max_temp_s = southern_hemisphere.iloc[:,3]
#Calculate Correlation Coefficient
print(f"The r-value is {round(st.pearsonr(lat_s,max_temp_s)[0],2)}")
(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = linregress(lat_s, max_temp_s)
# Create equation of line to calculate predicted violent crime rate
vc_fit = vc_slope * lat_s + vc_int
# Plot the linear model on top of scatter plot 
plt.figure(figsize=(10,7))
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.scatter(lat_s, max_temp_s,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

plt.plot(lat_s,vc_fit,"--")
plt.xlim(-60,10)
plt.ylim(min(southern_hemisphere['Max Temp']) - 17, max(southern_hemisphere['Max Temp']) + 20)
plt.title(f"Latitude vs. Max Temperature (South H.) ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.plot(lat_s,vc_fit,"--")
plt.show()
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\SH_Lat_MaxTemp_Fig6.png")
# Out:
# The r-value is 0.6

# %% [markdown]
# *Looking at the graph and linear regression and r-value above we can see that temperature rises with approach of equator
# *Temperature consequently drops as we approach South Pole
# *Note: Lienar regression is smaller on negative Latitude due to smaller number of data points and lowesr dat point is at
# *-55 Latitude

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Latitude North versus Humidity 
lat_n = northern_hemisphere.iloc[:,1]
humidity_n = northern_hemisphere.iloc[:,4]
#Calculate Correlation Coefficient
print(f"The r-value is {round(st.pearsonr(lat_n,humidity_n)[0],2)}")
(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = linregress(lat_n, humidity_n)
# Create equation of line to calculate predicted violent crime rate
vc_fit = vc_slope * lat_n + vc_int
# Plot the linear model on top of scatter plot 
plt.figure(figsize=(10,7))
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.scatter(lat_n, humidity_n,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

plt.plot(lat_n,vc_fit,"--")
plt.xlim(-10,90)
plt.ylim(min(northern_hemisphere['Humidity']) - 10, max(northern_hemisphere['Humidity']) + 20)
plt.title(f"Latitude vs. Humidity (North H.) ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Relative Humidity (%)")
plt.plot(lat_n,vc_fit,"--")
plt.show()
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\NH_Lat_Humidty_Fig7.png")
# Out:
# The r-value is 0.31

# %% [markdown]
# *Looking at the graph and linear regression above for Northern Hemisphere we can see that Humidity rises with
# *increase in Latitude
# *Note, our data collection has more data samples further north making linear regression and r-value more significant

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Latitude South versus Humidity 
lat_s = southern_hemisphere.iloc[:,1]
humidity_s = southern_hemisphere.iloc[:,4]
lat_s_mean = round(lat_s.mean(), 6)
humidity_s_mean = round(humidity_s.mean(), 6)
#Calculate Correlation Coefficient
print(f"The r-value is {round(st.pearsonr(lat_s,humidity_s)[0],4)}")
#print(f"The r-value is {r = np.corrcoef(lat_s,humidity_s)}")
#print(f"The r-value is {scipy.stats.pearsonr(lat_s, humidity_s)[0]}")
(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = linregress(lat_s, humidity_s)
# Create equation of line to calculate predicted violent crime rate
vc_fit = vc_slope * lat_s + vc_int
# Plot the linear model on top of scatter plot 
plt.figure(figsize=(10,7))
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.scatter(lat_s, humidity_s,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

plt.plot(lat_s,vc_fit,"--")
plt.xlim(-60,10)
plt.ylim(min(southern_hemisphere['Humidity'])-5, max(southern_hemisphere['Humidity']) + 20)
plt.title(f"Latitude vs. Humidity (South H.) ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Relative Humidity (%)")
plt.plot(lat_s,vc_fit,"--")
plt.show()
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\SH_Lat_Humidity_Fig8.png")
# Out:
# The r-value is 0.1063

# %% [markdown]
# *Looking at the graph and linear regression above for Southern Hemisphere we can see that Humidity increases with approach
# *of equator
# *Note: Southern Heisphere has less data points, so that is something to take into consideration, because our dat isnot evenly
# *distributed on both hemispheres

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Latitude North versus Cloudiness 
lat_n = northern_hemisphere.iloc[:,1]
cloudiness_n = northern_hemisphere.iloc[:,5]
#Calculate Correlation Coefficient
print(f"The r-value is {round(st.pearsonr(lat_n,cloudiness_n)[0],2)}")
(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = linregress(lat_n, cloudiness_n)
# Create equation of line to calculate predicted violent crime rate
vc_fit = vc_slope * lat_n + vc_int
# Plot the linear model on top of scatter plot 
plt.figure(figsize=(10,7))
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.scatter(lat_n, cloudiness_n,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

plt.plot(lat_n,vc_fit,"--")
plt.xlim(-10,90)
plt.ylim(min(northern_hemisphere['Cloudiness']) - 17, max(northern_hemisphere['Cloudiness']) + 20)
plt.title(f"Latitude vs. Cloudiness (%) (North H.) ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.show()
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\NH_Lat_Cloudiness_LR_Fig9.png")
# Out:
# The r-value is 0.13

# %% [markdown]
# *Looking at the graph and linear regression above for Northern Hemisphere we can see that Cloudiness rises with
# *increase in Latitude
# *Note, our data collection has more data samples further north making linear regression and r-value more significant

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Latitude South versus Clodiness 
lat_s = southern_hemisphere.iloc[:,1]
cloudiness_s = southern_hemisphere.iloc[:,5]
#Calculate Correlation Coefficient
print(f"The r-value is {round(st.pearsonr(lat_s,cloudiness_s)[0],4)}")

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = linregress(lat_s, cloudiness_s)
# Create equation of line to calculate predicted increase in cloudiness as altitude increases
vc_fit = vc_slope * lat_s + vc_int
# Plot the linear model on top of scatter plot 
plt.figure(figsize=(10,7))
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.scatter(lat_s, cloudiness_s,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

plt.plot(lat_s,vc_fit,"--")
plt.xlim(-60,10)
plt.ylim(min(southern_hemisphere['Cloudiness']) - 17, max(southern_hemisphere['Cloudiness']) + 20)
plt.title(f"Latitude vs. Cloudiness (South H.) ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Relative Cloudiness (%)")
plt.show()
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\SH_Lat_Cloudiness_LR_Fig10.png")
# Out:
# The r-value is 0.2135

# %% [markdown]
# *Looking at the graph and linear regression above for Southern Hemisphere we can see that Cloudiness rises with
# *approach of equator

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Latitude South versus Wind Speed 
lat_n = northern_hemisphere.iloc[:,1]
wind_speed_n= northern_hemisphere.iloc[:,6]
#Calculate Correlation Coefficient
print(f"The r-value is {round(st.pearsonr(lat_n,wind_speed_n)[0],4)}")

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = linregress(lat_n, wind_speed_n)
# Create equation of line to calculate predicted increase in wind speed as altitude increases
vc_fit = vc_slope * lat_n + vc_int
# Plot the linear model on top of scatter plot 
plt.figure(figsize=(10,7))
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.scatter(lat_n, wind_speed_n,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

plt.plot(lat_n,vc_fit,"--")
plt.xlim(-10,90)
plt.ylim(min(northern_hemisphere['Wind Speed']) -2, max(northern_hemisphere['Wind Speed']) + 2)
plt.title(f"Latitude vs. Wind Speed (Northern H.) ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\NH_Lat_WindSpeed_LR_Fig11.png")
# Out:
# The r-value is 0.0674

# %% [markdown]
# *Looking at the graph and linear regression above for Northern Hemisphere we can see that Wind Speed does't significantly
# *change with altitude, except for some outliers around Latitude +35
# *Note: Linear regression related to Wind Speed and Latitude in Northern Hemisphere isn't significant

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Latitude South versus Wind Speed 
lat_s = southern_hemisphere.iloc[:,1]
wind_speed_s = southern_hemisphere.iloc[:,6]
#Calculate Correlation Coefficient
print(f"The r-value is {round(st.pearsonr(lat_s,wind_speed_s)[0],4)}")

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = linregress(lat_s, wind_speed_s)
# Create equation of line to calculate predicted increase in wind speed as altitude increases
vc_fit = vc_slope * lat_s + vc_int
# Plot the linear model on top of scatter plot 
plt.figure(figsize=(10,7))
plt.grid(linestyle='-', linewidth='0.5', color='black')
plt.scatter(lat_s, wind_speed_s,
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

plt.plot(lat_s,vc_fit,"--")
plt.xlim(-60,10)
plt.ylim(min(southern_hemisphere['Wind Speed']), max(southern_hemisphere['Wind Speed']) + 2)
plt.title(f"Latitude vs. Wind Speed (South H.) ({date.today().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()
#Save Scatter Plot
plt.savefig(r"C:\Git\python-api-challenge\output_data_solved\SH_Lat_WindSpeed_LR_Fig12.png")
# Out:
# The r-value is -0.3061

# %% [markdown]
# *Looking at the graph and linear regression above for Southern Hemisphere we can see that Wind Speed is increasing as we go further South, but outliers make it more substantial
# *Note: There are some outliers around -55 Latitude making Linear regression more steep as we go further on the negative
# *Latitude

# %% [markdown]
# *Note, I have to rerun the code at last minute, so output file should be different from what I used for Vacationpy.
# *Originally, I saved all graphs in pdf format, but linear regression graphhs weren't visible, so I had to rereun the code and *export png files.
